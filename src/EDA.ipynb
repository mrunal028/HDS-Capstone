# %% [markdown]
# <a href="https://colab.research.google.com/github/mrunal028/HDS-Capstone/blob/main/src/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1be78dff-a537-4314-be7f-9198180978ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1be78dff-a537-4314-be7f-9198180978ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("heart_attack_dataset.csv")
print("Data loaded successfully!")
df.head()
# Out:
# Data loaded successfully!
#    Age  Gender  Cholesterol  BloodPressure  HeartRate   BMI  Smoker  Diabetes  \
# 0   31    Male          194            162         71  22.9       0         1
# 1   69    Male          208            148         93  33.9       1         1
# 2   34  Female          132            161         94  34.0       0         0
# 3   53    Male          268            134         91  35.0       0         1
# 4   57  Female          203            140         75  30.1       0         1
#
#    Hypertension  FamilyHistory  ...  ExerciseInducedAngina        Slope  \
# 0             0              0  ...                    Yes  Downsloping
# 1             0              0  ...                    Yes    Upsloping
# 2             1              1  ...                    Yes    Upsloping
# 3             1              0  ...                    Yes         Flat
# 4             0              0  ...                    Yes         Flat
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372974 entries, 0 to 372973
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Age                    372974 non-null  int64
#  1   Gender                 372974 non-null  object
#  2   Cholesterol            372974 non-null  int64
#  3   BloodPressure          372974 non-null  int64
#  4   HeartRate              372974 non-null  int64
#  5   BMI                    372974 non-null  float64
#  6   Smoker                 372974 non-null  int64
#  7   Diabetes               372974 non-null  int64
#  8   Hypertension           372974 non-null  int64
#  9   FamilyHistory          372974 non-null  int64
#  10  PhysicalActivity       372974 non-null  int64
#  11  AlcoholConsumption     372974 non-null  int64
#  12  Diet                   372974 non-null  object
#  13  StressLevel            372974 non-null  int64
# ...

# %%
# Basic information
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (372974, 32)

# %%
print("\nColumn data types:\n", df.dtypes)
# Out:
# Column data types:
#  Age                        int64
# Gender                    object
# Cholesterol                int64
# BloodPressure              int64
# HeartRate                  int64
# BMI                      float64
# Smoker                     int64
# Diabetes                   int64
# Hypertension               int64
# FamilyHistory              int64
# PhysicalActivity           int64
# AlcoholConsumption         int64
# Diet                      object
# StressLevel                int64
# Ethnicity                 object
# Income                     int64
# EducationLevel            object
# Medication                object
# ChestPainType             object
# ECGResults                object
# MaxHeartRate               int64
# ST_Depression            float64
# ExerciseInducedAngina     object
# Slope                     object
# NumberOfMajorVessels       int64
# Thalassemia               object
# PreviousHeartAttack        int64
# ...

# %%
# Basic information
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  Age                      0
# Gender                   0
# Cholesterol              0
# BloodPressure            0
# HeartRate                0
# BMI                      0
# Smoker                   0
# Diabetes                 0
# Hypertension             0
# FamilyHistory            0
# PhysicalActivity         0
# AlcoholConsumption       0
# Diet                     0
# StressLevel              0
# Ethnicity                0
# Income                   0
# EducationLevel           0
# Medication               0
# ChestPainType            0
# ECGResults               0
# MaxHeartRate             0
# ST_Depression            0
# ExerciseInducedAngina    0
# Slope                    0
# NumberOfMajorVessels     0
# Thalassemia              0
# PreviousHeartAttack      0
# StrokeHistory            0
# Residence                0
# EmploymentStatus         0
# MaritalStatus            0
# Outcome                  0
# dtype: int64

# %%
df.describe()
# Out:
#                  Age    Cholesterol  BloodPressure      HeartRate  \
# count  372974.000000  372974.000000  372974.000000  372974.000000
# mean       56.975151     199.455844     134.508234      89.495043
# std        15.867016      57.723381      25.984528      17.342658
# min        30.000000     100.000000      90.000000      60.000000
# 25%        43.000000     149.000000     112.000000      74.000000
# 50%        57.000000     199.000000     134.000000      89.000000
# 75%        71.000000     249.000000     157.000000     105.000000
# max        84.000000     299.000000     179.000000     119.000000
#
#                  BMI         Smoker       Diabetes   Hypertension  \
# count  372974.000000  372974.000000  372974.000000  372974.000000
# mean       29.006733       0.499225       0.500987       0.500973
# std         6.345460       0.500000       0.500000       0.500000
# min        18.000000       0.000000       0.000000       0.000000
# ...

# %%
# Categorical column summary
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    print(f"\nValue counts for {col}:\n", df[col].value_counts())
# Out:
# Value counts for Gender:
#  Gender
# Male      186770
# Female    186204
# Name: count, dtype: int64
#
# Value counts for Diet:
#  Diet
# Moderate     125079
# Healthy      124091
# Unhealthy    123804
# Name: count, dtype: int64
#
# Value counts for Ethnicity:
#  Ethnicity
# White       74969
# Asian       74942
# Black       74532
# Hispanic    74350
# Other       74181
# Name: count, dtype: int64
#
# Value counts for EducationLevel:
#  EducationLevel
# High School     124912
# College         124040
# Postgraduate    124022
# Name: count, dtype: int64
#
# Value counts for Medication:
#  Medication
# No     186526
# Yes    186448
# Name: count, dtype: int64
#
# Value counts for ChestPainType:
#  ChestPainType
# Asymptomatic    93609
# Atypical        93262
# Typical         93126
# Non-anginal     92977
# Name: count, dtype: int64
#
# Value counts for ECGResults:
#  ECGResults
# LV hypertrophy      124750
# ST-T abnormality    124227
# Normal              123997
# ...

# %%
# Create a histogram to visualize the distribution of the 'Age' column
# - bins=30: number of bins for the histogram
# - kde=True: includes a Kernel Density Estimate curve for smooth distribution
# - color='darkgreen': sets the color of the histogram bars and KDE line
sns.histplot(df["Age"], bins=30, kde=True, color="darkgreen")

# Set the title of the plot
plt.title("Distribution of Ages in Dataset")

# Label the x-axis
plt.xlabel("Age (in years)")

# Label the y-axis
plt.ylabel("Number of Individuals")

# Display the plot
plt.show()

# %%
# ===========================
# Plotting BMI Distribution
# ===========================

# Create a histogram to visualize the distribution of BMI in the dataset
# - figsize=(10, 6): sets the size of the figure for better readability
# - sns.histplot(df["BMI"], kde=True): plots the histogram with a KDE (Kernel Density Estimate) for smoothness
# - color='teal': changes the color of the histogram bars and the KDE line
plt.figure(figsize=(10, 6))
sns.histplot(df["BMI"], kde=True, color="teal")

# Set the title for the plot
plt.title("Distribution of BMI")

# Label the x-axis to indicate the variable being plotted
plt.xlabel("Body Mass Index (BMI)")

# Label the y-axis to indicate the frequency of occurrences
plt.ylabel("Frequency")

# Display the plot
plt.show()

# %%
# ================================
# Plotting Blood Pressure Distribution
# ================================

# Create a histogram to visualize the distribution of blood pressure in the dataset
# - figsize=(10, 6): sets the figure size for better readability
# - sns.histplot(df["BloodPressure"], kde=True): plots the histogram with a KDE curve for smoothness
# - color='skyblue': sets the color of the histogram bars and the KDE line to sky blue for a softer look
plt.figure(figsize=(10, 6))
sns.histplot(df["BloodPressure"], kde=True, color="skyblue")

# Set the title for the plot
plt.title("Blood Pressure Distribution")

# Label the x-axis to indicate the variable being plotted (Blood Pressure in mmHg)
plt.xlabel("Blood Pressure (mmHg)")

# Label the y-axis to indicate the frequency of occurrences
plt.ylabel("Frequency")

# Display the plot
plt.show()

# %%
# Create a count plot to visualize the frequency of each gender category
# - x="Gender": specifies the categorical variable to be plotted on the x-axis
# - data=df: specifies the DataFrame containing the data
# - palette='Set2': applies a different color palette for visual distinction
sns.countplot(x="Gender", data=df, palette="Set2")

# Set the title of the plot
plt.title("Count of Individuals by Gender")

# Label the x-axis
plt.xlabel("Gender")

# Label the y-axis
plt.ylabel("Number of Individuals")

# Display the plot
plt.show()

# %%
# ===============================
# Plotting Smoker Distribution
# ===============================

# Create a bar plot to visualize the distribution of smokers vs non-smokers
# - figsize=(8, 5): sets the size of the figure for better clarity
# - kind="bar": creates a bar plot to display the counts
# - color=["lightcoral", "seagreen"]: assigns custom colors for each category (non-smokers in light coral, smokers in sea green)
smoking_count = df["Smoker"].value_counts()
smoking_count.plot(kind="bar", color=["lightcoral", "seagreen"])

# Set the title for the plot
plt.title("Smoker vs. Non-Smoker Distribution")

# Label the x-axis to indicate the smoking status categories
plt.xlabel("Smoking Status")

# Label the y-axis to show the count of individuals in each category
plt.ylabel("Count of Individuals")

# Update x-axis ticks to show "Non-Smoker" and "Smoker" as labels
plt.xticks([0, 1], ["Non-Smoker", "Smoker"], rotation=0)

# Display the plot
plt.show()

# %%
# Correlation heatmap for numeric features
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Histograms for numeric columns
df.select_dtypes(include=np.number).hist(figsize=(15, 10), bins=30)
plt.suptitle("Histograms of Numeric Features")
plt.tight_layout()
plt.show()

# %%
# Boxplots to check for outliers
for col in df.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(6, 3))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
# Countplots for categorical features
for col in cat_cols:
    plt.figure(figsize=(6, 3))
    sns.countplot(x=df[col])
    plt.title(f"Countplot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Calculate and plot the correlation matrix for selected health-related columns
# - df[["Cholesterol", "BloodPressure", "BMI", "Diabetes", "Hypertension"]]: selects specific columns
# - .corr(): computes the pairwise correlation between features
# - annot=True: displays the correlation values in the heatmap cells
# - cmap='YlGnBu': sets the colormap to Yellow-Green-Blue for a fresh look
corr_matrix = df[["Cholesterol", "BloodPressure", "BMI", "Diabetes", "Hypertension"]].corr()
sns.heatmap(corr_matrix, annot=True, cmap="YlGnBu")

# Set the title of the heatmap
plt.title("Correlation Matrix of Health Indicators")

# Display the heatmap
plt.show()

# %%
# ========================
# Family History & Outcome
# ========================

# Create a count plot to visualize the relationship between FamilyHistory and Outcome
# - figsize=(6, 4): sets the size of the figure
# - x="FamilyHistory": plots Family History on the x-axis
# - hue="Outcome": differentiates the bars based on the Outcome (Heart Attack or No Heart Attack)
# - palette="Blues": changes the color palette to shades of blue
sns.countplot(x="FamilyHistory", hue="Outcome", data=df, palette="Blues")
plt.title("Family History vs. Heart Attack")  # Set plot title
plt.xlabel("Family History (Yes/No)")  # Label x-axis
plt.ylabel("Count of Individuals")  # Label y-axis
plt.show()

# %%
# ========================
# Exercise & Cardiac Health
# ========================

# Create a scatter plot to explore the relationship between Age and MaxHeartRate
# - figsize=(12, 5): sets the size of the figure
# - x="Age": plots Age on the x-axis
# - y="MaxHeartRate": plots Maximum Heart Rate on the y-axis
# - hue="Outcome": color points based on Heart Attack outcome
# - palette="viridis": applies a color palette with a smooth gradient
sns.scatterplot(x="Age", y="MaxHeartRate", hue="Outcome", data=df, palette="viridis")
plt.title("Max Heart Rate vs. Age")  # Set plot title
plt.xlabel("Age (in years)")  # Label x-axis
plt.ylabel("Maximum Heart Rate (bpm)")  # Label y-axis
plt.show()

# %%
# Create a boxplot to analyze the distribution of ST Depression across Heart Attack outcomes
# - x="Outcome": plots Heart Attack outcome (Yes/No) on the x-axis
# - y="ST_Depression": plots ST Depression levels on the y-axis
# - palette="pastel": sets the color palette to softer shades
plt.figure(figsize=(12, 5))
sns.boxplot(x="Outcome", y="ST_Depression", data=df, palette="pastel")
plt.title("ST Depression vs. Heart Attack")  # Set plot title
plt.xlabel("Heart Attack Outcome (Yes/No)")  # Label x-axis
plt.ylabel("ST Depression Levels")  # Label y-axis
plt.show()

# %%
# ========================
# Outcome Distribution
# ========================

# Create a pie chart to show the distribution of Heart Attack Outcomes
# - autopct="%1.1f%%": displays the percentage on the pie slices
# - colors=["darkblue", "red"]: sets custom colors for each slice (Heart Attack/No Heart Attack)
# - figsize=(6, 4): sets the figure size
plt.figure(figsize=(6, 4))
df["Outcome"].value_counts().plot(kind="pie", autopct="%1.1f%%", colors=["green", "orange"])
plt.title("Heart Attack Outcome Distribution")  # Set plot title
plt.ylabel("")  # Remove the y-axis label for aesthetic reasons
plt.show()

# %%
df.drop(columns=['AlcoholConsumption'], inplace=True)
print("AlcoholConsumption column removed.")
df.head()
# Out:
# AlcoholConsumption column removed.
#    Age  Gender  Cholesterol  BloodPressure  HeartRate   BMI  Smoker  Diabetes  \
# 0   31    Male          194            162         71  22.9       0         1
# 1   69    Male          208            148         93  33.9       1         1
# 2   34  Female          132            161         94  34.0       0         0
# 3   53    Male          268            134         91  35.0       0         1
# 4   57  Female          203            140         75  30.1       0         1
#
#    Hypertension  FamilyHistory  ...  ExerciseInducedAngina        Slope  \
# 0             0              0  ...                    Yes  Downsloping
# 1             0              0  ...                    Yes    Upsloping
# 2             1              1  ...                    Yes    Upsloping
# 3             1              0  ...                    Yes         Flat
# 4             0              0  ...                    Yes         Flat
#
# ...

# %%
# Descriptive stats
print(df.describe())
print(df.info())

# Bivariate analysis: correlations
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
# Out:
#                  Age    Cholesterol  BloodPressure      HeartRate  \
# count  372974.000000  372974.000000  372974.000000  372974.000000
# mean       56.975151     199.455844     134.508234      89.495043
# std        15.867016      57.723381      25.984528      17.342658
# min        30.000000     100.000000      90.000000      60.000000
# 25%        43.000000     149.000000     112.000000      74.000000
# 50%        57.000000     199.000000     134.000000      89.000000
# 75%        71.000000     249.000000     157.000000     105.000000
# max        84.000000     299.000000     179.000000     119.000000
#
#                  BMI         Smoker       Diabetes   Hypertension  \
# count  372974.000000  372974.000000  372974.000000  372974.000000
# mean       29.006733       0.499225       0.500987       0.500973
# std         6.345460       0.500000       0.500000       0.500000
# min        18.000000       0.000000       0.000000       0.000000
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# ✅ 1. Feature Engineering
df['Stress_Activity_Ratio'] = df['StressLevel'] / (df['PhysicalActivity'] + 1)
df['Age_BMI_Interaction'] = df['Age'] * df['BMI']
df['IsHighRisk'] = ((df['Cholesterol'] > 240) &
                    (df['BloodPressure'] > 140) &
                    (df['Smoker'] == 1)).astype(int)

# ✅ 2. Separate target before encoding
y = df['Outcome']
X = df.drop(columns=['Outcome'])

# ✅ 3. Encode categorical variables
X_encoded = pd.get_dummies(X, drop_first=True)

# ✅ 4. Train/test split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# ✅ 5. Feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# ✅ 6. Train Random Forest
model = RandomForestClassifier(random_state=42)
model.fit(X_train_scaled, y_train)

# ✅ 7. Predictions and Evaluation
y_pred = model.predict(X_test_scaled)
y_proba = model.predict_proba(X_test_scaled)[:, 1]

print("📊 Classification Report:")
print(classification_report(y_test, y_pred))

print("🔍 ROC-AUC Score:", roc_auc_score(y_test, y_proba))
# Out:
# 📊 Classification Report:
#                  precision    recall  f1-score   support
#
#    Heart Attack       0.50      0.54      0.52     37003
# No Heart Attack       0.50      0.46      0.48     37592
#
#        accuracy                           0.50     74595
#       macro avg       0.50      0.50      0.50     74595
#    weighted avg       0.50      0.50      0.50     74595
#
# 🔍 ROC-AUC Score: 0.49931065748699494

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (372974, 34)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372974 entries, 0 to 372973
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Age                    372974 non-null  int64
#  1   Gender                 372974 non-null  object
#  2   Cholesterol            372974 non-null  int64
#  3   BloodPressure          372974 non-null  int64
#  4   HeartRate              372974 non-null  int64
#  5   BMI                    372974 non-null  float64
#  6   Smoker                 372974 non-null  int64
#  7   Diabetes               372974 non-null  int64
#  8   Hypertension           372974 non-null  int64
#  9   FamilyHistory          372974 non-null  int64
#  10  PhysicalActivity       372974 non-null  int64
#  11  Diet                   372974 non-null  object
#  12  StressLevel            372974 non-null  int64
#  13  Ethnicity              372974 non-null  object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
